# %%
import random

# %%
## 20명의 국어, 영어, 수학 점수 리스트 [국어점수, 영어점수, 수학점수]
sc = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc.append(scc)
print(sc)
# Out:
# [[35, 7, 22], [11, 25, 68], [57, 69, 19], [86, 49, 9], [85, 78, 38], [65, 78, 63], [65, 73, 98], [92, 17, 96], [73, 13, 89], [78, 71, 85], [39, 39, 78], [89, 18, 88], [76, 87, 89], [81, 20, 78], [33, 47, 85], [87, 29, 29], [70, 51, 19], [71, 90, 41], [76, 68, 77], [43, 3, 72]]

# %%
## 4개 반(한 학년)의 국어, 영어, 수학 점수 리스트
sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl = [sc_1,sc_2,sc_3,sc_4]
print(cl)
# Out:
# [[[95, 25, 99], [84, 74, 88], [27, 94, 12], [49, 51, 76], [43, 31, 31], [10, 39, 11], [56, 43, 68], [35, 78, 66], [21, 3, 50], [57, 20, 64], [14, 90, 97], [44, 88, 52], [70, 25, 45], [51, 59, 41], [97, 22, 80], [74, 28, 90], [27, 11, 84], [6, 47, 23], [85, 3, 66], [44, 49, 93]], [[30, 41, 0], [34, 38, 78], [26, 47, 27], [65, 98, 32], [97, 89, 9], [88, 48, 60], [24, 79, 87], [44, 22, 48], [31, 96, 56], [83, 18, 15], [14, 26, 52], [14, 46, 68], [72, 19, 5], [54, 81, 52], [44, 58, 63], [94, 23, 53], [78, 44, 54], [5, 94, 37], [91, 89, 49], [69, 96, 5]], [[53, 44, 45], [8, 3, 97], [33, 85, 26], [72, 31, 12], [96, 4, 31], [91, 16, 58], [62, 69, 4], [100, 44, 11], [63, 18, 27], [84, 52, 44], [66, 25, 15], [79, 56, 62], [18, 32, 75], [98, 84, 14], [30, 66, 89], [8, 52, 96], [6, 27, 25], [16, 22, 64], [100, 35, 97], [91, 21, 81]], [[84, 69, 65], [90, 92, 90], [77, 1, 25], [92, 99, 94], [82, 28, 86], [36, 88, 68], [44, 84, 37], [31, 92, 6], [97, 3, 51], [91, 94, 8], [97, 31, 55], [11, 52, 99]
# ...

# %%
## 학년별 반별 국어,영어,수학 점수 리스트 [[[1반[국,영,수]],[2반[국,영,수]],[3반[국,영,수]],[4반[국,영,수]]]
sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl_1 = [sc_1,sc_2,sc_3,sc_4]

sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl_2 = [sc_1,sc_2,sc_3,sc_4]

sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl_3 = [sc_1,sc_2,sc_3,sc_4]

sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl_4 = [sc_1,sc_2,sc_3,sc_4]

sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl_5 = [sc_1,sc_2,sc_3,sc_4]

sc_1 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_1.append(scc)
sc_2 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_2.append(scc)
sc_3 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_3.append(scc)
sc_4 = []
for i in range(20):
    k = random.randint(0,100)
    e = random.randint(0,100)
    m = random.randint(0,100)
    scc = [k,e,m]
    sc_4.append(scc)

cl_6 = [sc_1,sc_2,sc_3,sc_4]

print(cl_1)
print(cl_2)
print(cl_3)
print(cl_4)
print(cl_5)
print(cl_6)
# Out:
# [[[48, 2, 50], [49, 71, 35], [56, 68, 5], [63, 40, 64], [62, 53, 99], [30, 8, 11], [11, 6, 9], [91, 12, 25], [7, 51, 63], [76, 63, 87], [86, 76, 78], [26, 73, 65], [21, 17, 9], [53, 8, 16], [67, 33, 30], [44, 61, 91], [73, 7, 38], [62, 50, 68], [35, 75, 67], [76, 65, 97]], [[37, 46, 0], [66, 81, 29], [99, 69, 59], [99, 18, 70], [51, 61, 61], [91, 32, 20], [4, 37, 57], [70, 60, 80], [13, 100, 30], [90, 10, 54], [36, 16, 51], [69, 4, 89], [85, 60, 12], [24, 88, 55], [73, 99, 79], [20, 64, 75], [59, 36, 94], [62, 59, 54], [2, 81, 49], [96, 95, 89]], [[29, 12, 95], [75, 70, 64], [52, 61, 18], [49, 22, 63], [1, 36, 99], [27, 42, 97], [63, 6, 70], [22, 48, 77], [55, 44, 17], [5, 19, 56], [23, 55, 23], [66, 89, 8], [63, 45, 65], [70, 61, 10], [65, 1, 74], [92, 42, 98], [33, 35, 96], [64, 97, 16], [23, 25, 53], [58, 71, 50]], [[76, 39, 3], [18, 89, 55], [81, 71, 93], [68, 90, 58], [5, 13, 18], [67, 46, 26], [77, 42, 27], [63, 77, 97], [42, 10, 58], [65, 12, 31], [66, 60, 2], [65, 3, 31], [49
# ...

# %%
# 1학년 반별 과목의 평균 점수
# 1학년 1반의 국어 점수
a_1 = []
for i in range(20):
    a_k = cl_1[0][i][0]
    a_1.append(a_k)
# print(a_1)
# 1학년 1반의 영어 점수
b_1 = []
for i in range(20):
    b_e = cl_1[0][i][1]
    b_1.append(b_e)
# print(b_1)
# 1학년 1반의 수학 점수
c_1 = []
for i in range(20):
    c_m = cl_1[0][i][2]
    c_1.append(c_m)
# print(c_1)
## 1학년 1반의 국어,영어,수학의 평균 점수
avg_a_1 = sum(a_1)/20
avg_b_1 = sum(b_1)/20
avg_c_1 = sum(c_1)/20
print("1학년 1반의 국어 평균 점수 : ",avg_a_1)
print("1학년 1반의 영어 평균 점수 : ",avg_b_1)
print("1학년 1반의 수학 평균 점수 : ",avg_c_1)

# 1학년 2반의 국어,영어,수학의 평균 점수...
a_2 = []
for i in range(20):
    a_k = cl_1[1][i][0]
    a_2.append(a_k)

b_2 = []
for i in range(20):
    b_e = cl_1[1][i][1]
    b_2.append(b_e)

c_2 = []
for i in range(20):
    c_m = cl_1[1][i][2]
    c_2.append(c_m)
avg_a_2 = sum(a_2)/20
avg_b_2 = sum(b_2)/20
avg_c_2 = sum(c_2)/20
print("1학년 2반의 국어 평균 점수 : ",avg_a_2)
print("1학년 2반의 영어 평균 점수 : ",avg_b_2)
print("1학년 2반의 수학 평균 점수 : ",avg_c_2)

# 1학년 3반의 국어,영어,수학의 평균 점수
a_3 = []
for i in range(20):
    a_k = cl_1[2][i][0]
    a_3.append(a_k)

b_3 = []
for i in range(20):
    b_e = cl_1[2][i][1]
    b_3.append(b_e)

c_3 = []
for i in range(20):
    c_m = cl_1[2][i][2]
    c_3.append(c_m)
avg_a_3 = sum(a_3)/20
avg_b_3 = sum(b_3)/20
avg_c_3 = sum(c_3)/20
print("1학년 3반의 국어 평균 점수 : ",avg_a_3)
print("1학년 3반의 영어 평균 점수 : ",avg_b_3)
print("1학년 3반의 수학 평균 점수 : ",avg_c_3)

# 1학년 4반의 국어,영어,수학의 평균 점수
a_4 = []
for i in range(20):
    a_k = cl_1[3][i][0]
    a_4.append(a_k)

b_4 = []
for i in range(20):
    b_e = cl_1[3][i][1]
    b_4.append(b_e)

c_4 = []
for i in range(20):
    c_m = cl_1[3][i][2]
    c_4.append(c_m)
avg_a_4 = sum(a_4)/20
avg_b_4 = sum(b_4)/20
avg_c_4 = sum(c_4)/20
print("1학년 4반의 국어 평균 점수 : ",avg_a_4)
print("1학년 4반의 영어 평균 점수 : ",avg_b_4)
print("1학년 4반의 수학 평균 점수 : ",avg_c_4)
# Out:
# 1학년 1반의 국어 평균 점수 :  51.8
# 1학년 1반의 영어 평균 점수 :  41.95
# 1학년 1반의 수학 평균 점수 :  50.35
# 1학년 2반의 국어 평균 점수 :  57.3
# 1학년 2반의 영어 평균 점수 :  55.8
# 1학년 2반의 수학 평균 점수 :  55.35
# 1학년 3반의 국어 평균 점수 :  46.75
# 1학년 3반의 영어 평균 점수 :  44.05
# 1학년 3반의 수학 평균 점수 :  57.45
# 1학년 4반의 국어 평균 점수 :  46.0
# 1학년 4반의 영어 평균 점수 :  43.9
# 1학년 4반의 수학 평균 점수 :  49.9

# %%
# 2학년 반별 국어,영어,수학 평균 점수
# 2학년 1반 국어,영어,수학 평균 점수
a_1 = []
for i in range(20):
    a_k = cl_2[0][i][0]
    a_1.append(a_k)

b_1 = []
for i in range(20):
    b_e = cl_2[0][i][1]
    b_1.append(b_e)

c_1 = []
for i in range(20):
    c_m = cl_2[0][i][2]
    c_1.append(c_m)
avg_a_1 = sum(a_1)/20
avg_b_1 = sum(b_1)/20
avg_c_1 = sum(c_1)/20
print("2학년 1반의 국어 평균 점수 : ",avg_a_1)
print("2학년 1반의 영어 평균 점수 : ",avg_b_1)
print("2학년 1반의 수학 평균 점수 : ",avg_c_1)

# 2학년 2반 국어,영어,수학 평균
a_2 = []
for i in range(20):
    a_k = cl_2[1][i][0]
    a_2.append(a_k)

b_2 = []
for i in range(20):
    b_e = cl_2[1][i][1]
    b_2.append(b_e)

c_2 = []
for i in range(20):
    c_m = cl_2[1][i][2]
    c_2.append(c_m)
avg_a_2 = sum(a_2)/20
avg_b_2 = sum(b_2)/20
avg_c_2 = sum(c_2)/20
print("2학년 2반의 국어 평균 점수 : ",avg_a_2)
print("2학년 2반의 영어 평균 점수 : ",avg_b_2)
print("2학년 2반의 수학 평균 점수 : ",avg_c_2)

# 2학년 3반 국영수 평균
a_3 = []
for i in range(20):
    a_k = cl_2[2][i][0]
    a_3.append(a_k)

b_3 = []
for i in range(20):
    b_e = cl_2[2][i][1]
    b_3.append(b_e)

c_3 = []
for i in range(20):
    c_m = cl_2[2][i][2]
    c_3.append(c_m)
avg_a_3 = sum(a_3)/20
avg_b_3 = sum(b_3)/20
avg_c_3 = sum(c_3)/20
print("2학년 3반의 국어 평균 점수 : ",avg_a_3)
print("2학년 3반의 영어 평균 점수 : ",avg_b_3)
print("2학년 3반의 수학 평균 점수 : ",avg_c_3)

# 2-4 국영수 평균
a_4 = []
for i in range(20):
    a_k = cl_2[3][i][0]
    a_4.append(a_k)

b_4 = []
for i in range(20):
    b_e = cl_2[3][i][1]
    b_4.append(b_e)

c_4 = []
for i in range(20):
    c_m = cl_2[3][i][2]
    c_4.append(c_m)
avg_a_4 = sum(a_4)/20
avg_b_4 = sum(b_4)/20
avg_c_4 = sum(c_4)/20
print("2학년 4반의 국어 평균 점수 : ",avg_a_4)
print("2학년 4반의 영어 평균 점수 : ",avg_b_4)
print("2학년 4반의 수학 평균 점수 : ",avg_c_4)
# Out:
# 2학년 1반의 국어 평균 점수 :  58.75
# 2학년 1반의 영어 평균 점수 :  43.15
# 2학년 1반의 수학 평균 점수 :  53.55
# 2학년 2반의 국어 평균 점수 :  52.45
# 2학년 2반의 영어 평균 점수 :  49.95
# 2학년 2반의 수학 평균 점수 :  53.55
# 2학년 3반의 국어 평균 점수 :  48.05
# 2학년 3반의 영어 평균 점수 :  50.35
# 2학년 3반의 수학 평균 점수 :  63.85
# 2학년 4반의 국어 평균 점수 :  50.05
# 2학년 4반의 영어 평균 점수 :  56.4
# 2학년 4반의 수학 평균 점수 :  52.45
